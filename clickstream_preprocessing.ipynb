# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r'podaci\clickstream+data+for+online+shopping\e-shop clothing 2008.csv', encoding='cp1252', sep=';')
print(df.columns)
# Out:
# Index(['year', 'month', 'day', 'order', 'country', 'session ID',
#        'page 1 (main category)', 'page 2 (clothing model)', 'colour',
#        'location', 'model photography', 'price', 'price 2', 'page'],
#       dtype='object')

# %%
df.rename(columns={'page 1 (main category)': 'main category','page 2 (clothing model)':'clothing model'},inplace=True)

# %%
df
# Out:
#         year  month  day  order  country  session ID  main category  \
# 0       2008      4    1      1       29           1              1
# 1       2008      4    1      2       29           1              1
# 2       2008      4    1      3       29           1              2
# 3       2008      4    1      4       29           1              2
# 4       2008      4    1      5       29           1              2
# ...      ...    ...  ...    ...      ...         ...            ...
# 165469  2008      8   13      1       29       24024              2
# 165470  2008      8   13      1        9       24025              1
# 165471  2008      8   13      1       34       24026              1
# 165472  2008      8   13      2       34       24026              3
# 165473  2008      8   13      3       34       24026              2
#
#        clothing model  colour  location  model photography  price  price 2  \
# ...

# %%
print(df.isnull().sum())
# Out:
# year                 0
# month                0
# day                  0
# order                0
# country              0
# session ID           0
# main category        0
# clothing model       0
# colour               0
# location             0
# model photography    0
# price                0
# price 2              0
# page                 0
# dtype: int64

# %%
df_encoded = df.copy()

label_cols = df_encoded.select_dtypes(include='object').columns
for col in label_cols:
    df_encoded[col] = LabelEncoder().fit_transform(df_encoded[col])


df_encoded
# Out:
#         year  month  day  order  country  session ID  main category  \
# 0       2008      4    1      1       29           1              1
# 1       2008      4    1      2       29           1              1
# 2       2008      4    1      3       29           1              2
# 3       2008      4    1      4       29           1              2
# 4       2008      4    1      5       29           1              2
# ...      ...    ...  ...    ...      ...         ...            ...
# 165469  2008      8   13      1       29       24024              2
# 165470  2008      8   13      1        9       24025              1
# 165471  2008      8   13      1       34       24026              1
# 165472  2008      8   13      2       34       24026              3
# 165473  2008      8   13      3       34       24026              2
#
#         clothing model  colour  location  model photography  price  price 2  \
# ...

# %%
df_encoded.to_csv(r'podaci\clickstream+data+for+online+shopping\e-shop clothing 2008 preprocessed.csv', index=False)

# %%
df = pd.read_csv(r'podaci\clickstream+data+for+online+shopping\e-shop clothing 2008 preprocessed.csv', encoding='cp1252', sep=',')  
df
# Out:
#         year  month  day  order  country  session ID  main category  \
# 0       2008      4    1      1       29           1              1
# 1       2008      4    1      2       29           1              1
# 2       2008      4    1      3       29           1              2
# 3       2008      4    1      4       29           1              2
# 4       2008      4    1      5       29           1              2
# ...      ...    ...  ...    ...      ...         ...            ...
# 165469  2008      8   13      1       29       24024              2
# 165470  2008      8   13      1        9       24025              1
# 165471  2008      8   13      1       34       24026              1
# 165472  2008      8   13      2       34       24026              3
# 165473  2008      8   13      3       34       24026              2
#
#         clothing model  colour  location  model photography  price  price 2  \
# ...
